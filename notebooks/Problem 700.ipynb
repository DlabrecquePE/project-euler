# %%
factor, modulus = 1504170715041707, 4503599627370517
euler_coins, min_coin, n = [factor], factor, 1
while True:
    test_coin = (factor * n) % modulus
    if test_coin < min_coin:
        min_coin = test_coin
        euler_coins.append(min_coin)
        print(n, min_coin)
    n += 1 if n < 12263410 else 283827021
# print(sum(euler_coins))
# Out:
# 3 8912517754604
# 506 2044785486369
# 2527 1311409677241
# 4548 578033868113
# 11117 422691927098
# 17686 267349986083
# 24255 112008045068
# 55079 68674149121
# 85903 25340253174
# 202630 7346610401
# 724617 4046188430
# 1246604 745766459
# 6755007 428410324
# 12263410 111054189
# 296090431 110645024
# 579917452 110235859
# 863744473 109826694
# 1147571494 109417529
# 1431398515 109008364
# 1715225536 108599199
# 1999052557 108190034
# 2282879578 107780869
# 2566706599 107371704
# 2850533620 106962539
# 3134360641 106553374
# 3418187662 106144209
# 3702014683 105735044
# 3985841704 105325879
# 4269668725 104916714
# 4553495746 104507549
# 4837322767 104098384
# 5121149788 103689219
# 5404976809 103280054
# 5688803830 102870889
# 5972630851 102461724
# 6256457872 102052559
# 6540284893 101643394
# 6824111914 101234229
# 7107938935 100825064
# 7391765956 100415899
# 7675592977 100006734
# 7959419998 99597569
# 8243247019 99188404
# 8527074040 98779239
# 8810901061 98370074
# ...

# %%
print(sum(euler_coins))
# Out:
# 1517941219718360

# %%
print(sum(euler_coins[:2]))
# Out:
# 1513083232796311
